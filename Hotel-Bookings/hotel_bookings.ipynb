# %% [markdown]
# IMPORTING LIBRARIES

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# LOADING THE DATASET

# %%
df = pd.read_csv("hotel_booking.csv")

# %% [markdown]
# EXPLORATORY DATA ANALYSIS AND CLEANING

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df.shape
# Out:
# (119390, 36)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df["reservation_status_date"] = pd.to_datetime(df["reservation_status_date"])

# The column "reservation_status_date" is in string which may prevent us from further analysis this has been changed to data_time formart for further analysis

# %%
df.describe(include = "object")
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status             name  \
# count        119390        119390             119390           119390
# unique            3             4                  3            81503
# top      No Deposit     Transient          Check-Out  Michael Johnson
# ...

# %%
for col in df.describe(include = "object").columns:
    print(col)
    print(df[col].unique())
    print("-"*50)

# We have used a for loop to veiw all the categorical values in the column
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# --------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# --------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# --------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.drop(["agent", "company"], axis = 1, inplace = True)
df.dropna(inplace = True)

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483168     106.903309           0.707459
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
df["adr"].plot(kind = "box")

# From the box plot we can observe that "adr" has one outlier which is to be removed
# Out:
# <Axes: >

# %%
df = df[df["adr"]<5000]

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483167     106.903570           0.707462
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %% [markdown]
# DATA ANALYSIS AND VISUALIZATION

# %%
cancelled_perc = df["is_canceled"].value_counts(normalize = True).round(2) 
print(cancelled_perc)

plt.figure(figsize = (5,4))
plt.title("Reservation status")
plt.bar(["Not canceled", "Canceled"], df["is_canceled"].value_counts(), edgecolor = 'k', width = 0.7)
plt.show()


# The booking cancelation status here is that 62% of hotel bookings are not canceled but 37%  of hotel bookings are still canceled. 
# This cancellation % may not  seem like a huge number in comparison to 62% but 37% is still a high number.  
# The figure shows that the cancelation is more than half, which seems alarming.
# Out:
# is_canceled
# 0    0.63
# 1    0.37
# Name: proportion, dtype: float64

# %%
plt.figure(figsize = (8,4))
ax1 = sns.countplot(x = "hotel", hue = "is_canceled", data = df, palette = "Blues")
legend_labels,_ = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1,1))
plt.title("Reservation status in different hotels", size = 20)
plt.xlabel("Hotel")
plt.ylabel("Number of reservation")
plt.legend(["not canceled", "canceled"])
plt.show()

# Comparing Resort hotels and city hotels we see that city hotels have the highest cancelation rates.

# %%
resort_hotel = df[df["hotel"] == "Resort Hotel"]
resort_hotel["is_canceled"].value_counts(normalize = True).round(2)

# The resort hotel cancelation is 27 %
# Out:
# is_canceled
# 0    0.72
# 1    0.28
# Name: proportion, dtype: float64

# %%
city_hotel = df[df["hotel"] == "City Hotel"]
city_hotel["is_canceled"].value_counts(normalize = True).round(2)

# The city hotel cancelation is 41 %
# Out:
# is_canceled
# 0    0.58
# 1    0.42
# Name: proportion, dtype: float64

# %%
resort_hotel = resort_hotel.groupby("reservation_status_date")[["adr"]].mean()
city_hotel = city_hotel.groupby("reservation_status_date")[["adr"]].mean()

# %%
plt.figure(figsize = (20,8))
plt.title("Average Daily Rate In City And Resort Hotel", fontsize = 30)
plt.plot(resort_hotel.index, resort_hotel["adr"], label = "Resort hotel")
plt.plot(city_hotel.index, city_hotel["adr"], label = "Resort hotel")
plt.legend(fontsize = 15)
plt.show()

# According to the figure, the average daily rate for city hotels is less than the resort hotels
# The spikes indicate the rise in prices for hotels on weekends or holidays.
# The price for city hotels is less than resort hotels

# %%
df["month"] = df["reservation_status_date"].dt.strftime('%B')

# df["month"] = df["reservation_status_date"].dt.month

plt.figure(figsize = (16,8))
ax1 = sns.countplot(x = "month", hue = "is_canceled", data = df, palette = "bright")
legend_labels,_ = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1,1))
plt.title("Reservation status per month", size = 30)
plt.xlabel("Month")
plt.ylabel("Number of reservation")
plt.legend(["not canceled", "canceled"])
plt.show()

# In the graph we can see that the cancelation is higher when the reservation is high which does not give us a clear picture about the cancelation

# %%
plt.figure(figsize=(14, 8))
plt.title("ADR Per Month", fontsize = 20)
adr_per_month = df[df["is_canceled"] == 1].groupby("month")[["adr"]].sum().reset_index()
sns.barplot(x = "month", y = "adr", data = adr_per_month, edgecolor = 'k', width = 0.5)
plt.show()

# The month with the higher "Average daily rate" has the highest cancelation.
# From the above graph January has the highest cancelation which is explained by the graph given below which has the highest adr per month.

# %%
cancelled_data = df[df["is_canceled"] == 1]
top_10_country = cancelled_data["country"].value_counts()[:10]
plt.figure(figsize = (8,8))
plt.title("Top 10 countries with reservation cancellation", fontsize = 20)
plt.pie(top_10_country, autopct = "%.2f", labels = top_10_country.index)
plt.show()

# Portugal has the highest cancellation. Hotels need to be more aware and provide more facilities to people from Portugal.

# %%
df["market_segment"].value_counts()
# Out:
# market_segment
# Online TA        56402
# Offline TA/TO    24159
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: count, dtype: int64

# %%
df["market_segment"].value_counts(normalize = True).round(2)

# Majority of the hotel reservations are mostly done through online travel agent.
# Out:
# market_segment
# Online TA        0.47
# Offline TA/TO    0.20
# Groups           0.17
# Direct           0.10
# Corporate        0.04
# Complementary    0.01
# Aviation         0.00
# Name: proportion, dtype: float64

# %%
cancelled_data["market_segment"].value_counts(normalize = True).round(2)

# According to this data majority of the hotel cancelation is also through online travel agent.
# Out:
# market_segment
# Online TA        0.47
# Groups           0.27
# Offline TA/TO    0.19
# Direct           0.04
# Corporate        0.02
# Complementary    0.00
# Aviation         0.00
# Name: proportion, dtype: float64

# %%
cancelled_df_adr = cancelled_data.groupby("reservation_status_date")[["adr"]].mean().round(2)                
cancelled_df_adr.reset_index(inplace = True)
cancelled_df_adr.sort_values("reservation_status_date", inplace = True)
cancelled_df_adr
# Out:
#     reservation_status_date     adr
# 0                2014-10-17   62.80
# 1                2014-11-18    0.00
# 2                2015-01-01   62.06
# 3                2015-01-02    9.63
# 4                2015-01-18    0.00
# ..                      ...     ...
# 897              2017-08-26  178.20
# 898              2017-08-27  167.30
# 899              2017-08-28   81.42
# 900              2017-08-29  144.25
# 901              2017-08-31  189.75
#
# [902 rows x 2 columns]

# %%
not_cancelled_data = df[df["is_canceled"] == 0]
not_cancelled_df_adr = not_cancelled_data.groupby("reservation_status_date")[["adr"]].mean().round(2)                
not_cancelled_df_adr.reset_index(inplace = True)
not_cancelled_df_adr.sort_values("reservation_status_date", inplace = True)
not_cancelled_df_adr
# Out:
#     reservation_status_date     adr
# 0                2015-07-01   31.65
# 1                2015-07-02   95.92
# 2                2015-07-03   97.65
# 3                2015-07-04  110.48
# 4                2015-07-05  100.31
# ..                      ...     ...
# 800              2017-09-08  101.01
# 801              2017-09-09  147.78
# 802              2017-09-10  145.27
# 803              2017-09-12  153.57
# 804              2017-09-14  105.93
#
# [805 rows x 2 columns]

# %%
plt.figure(figsize = (20,6))
plt.title("Average Daily Rate", fontsize = 20)
plt.plot(not_cancelled_df_adr["reservation_status_date"], not_cancelled_df_adr["adr"], label = "not_cancelled") 
plt.plot(cancelled_df_adr["reservation_status_date"], cancelled_df_adr["adr"], label = "cancelled") 
plt.legend(fontsize = 15)
plt.show()

# The data here seems to be spread and messy to understand

# %%
# Filter data between 2016 and September 2017

cancelled_df_adr = cancelled_df_adr[(cancelled_df_adr["reservation_status_date"]>"2016") & (cancelled_df_adr["reservation_status_date"]<"2017-09")]
not_cancelled_df_adr = not_cancelled_df_adr[(not_cancelled_df_adr["reservation_status_date"]>"2016") & (not_cancelled_df_adr["reservation_status_date"]<"2017-09")] 

not_cancelled_df_adr
# Out:
#     reservation_status_date     adr
# 185              2016-01-02  143.15
# 186              2016-01-03  100.78
# 187              2016-01-04   76.91
# 188              2016-01-05   82.53
# 189              2016-01-06   63.24
# ..                      ...     ...
# 788              2017-08-27  152.49
# 789              2017-08-28  150.25
# 790              2017-08-29  149.11
# 791              2017-08-30  172.94
# 792              2017-08-31  161.50
#
# [608 rows x 2 columns]

# %%
# Filter data between 2016 and September 2017
cancelled_df_adr = cancelled_df_adr[(cancelled_df_adr["reservation_status_date"] > "2016") & (cancelled_df_adr["reservation_status_date"] < "2017-09")]
not_cancelled_df_adr = not_cancelled_df_adr[(not_cancelled_df_adr["reservation_status_date"] > "2016") & (not_cancelled_df_adr["reservation_status_date"] < "2017-09")]
cancelled_df_adr
# Out:
#     reservation_status_date     adr
# 295              2016-01-02   88.15
# 296              2016-01-03   93.05
# 297              2016-01-04   68.43
# 298              2016-01-05   82.81
# 299              2016-01-06   76.85
# ..                      ...     ...
# 897              2017-08-26  178.20
# 898              2017-08-27  167.30
# 899              2017-08-28   81.42
# 900              2017-08-29  144.25
# 901              2017-08-31  189.75
#
# [607 rows x 2 columns]

# %%
cancelled_df_adr = cancelled_df_adr[(cancelled_df_adr["reservation_status_date"]>"2016") & (cancelled_df_adr["reservation_status_date"]<"2017-09")]
not_cancelled_df_adr = not_cancelled_df_adr[(not_cancelled_df_adr["reservation_status_date"]>"2016") & (not_cancelled_df_adr["reservation_status_date"]<"2017-09")] 

plt.figure(figsize = (20,6))
plt.title("Average Daily Rate", fontsize = 20)
plt.plot(not_cancelled_df_adr["reservation_status_date"], not_cancelled_df_adr["adr"], label = "not_cancelled") 
plt.plot(cancelled_df_adr["reservation_status_date"], cancelled_df_adr["adr"], label = "cancelled") 
plt.legend(fontsize = 15)
plt.show()

# The data here is filtered from 2016 to September 2017.
# As the average daily rate increases the cancellation also increases as the average daily rate decreases the the cancelation also decreases.
